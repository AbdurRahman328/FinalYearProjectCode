# %% [markdown]
# ##Importing Libraries

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
plt.style.use('ggplot')

import tensorflow as tf
# %load_ext tensorboard

import warnings
warnings.filterwarnings('ignore')

import os
import datetime as dt
# Out:
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow import keras
from tensorflow.keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import time
import math

# %% [markdown]
# ## Importing Dataset and changing index as Date

# %%
data = pd.read_csv("D:\Final Year Project\Dataset\Proposed Paper Dataset\S&P 500\gspc_final.csv")
data.head()
# Out:
#          Date         Open        Close         SAR      MACD  RSI  ATR  MFI  \
# 0  03-01-2006  1248.290039  1268.800049         NaN  0.000000  NaN  NaN  NaN
# 1  04-01-2006  1268.800049  1273.459961  1245.73999  0.196947  NaN  NaN  NaN
# 2  05-01-2006  1273.459961  1273.479980  1245.73999  0.371553  NaN  NaN  NaN
# 3  06-01-2006  1273.479980  1285.449951  1245.73999  1.030907  NaN  NaN  NaN
# 4  09-01-2006  1285.449951  1290.150024  1245.73999  1.810155  NaN  NaN  NaN
#
#         USDX    VIX  EFFR  UNRATE  UMSCENT
# 0  89.839996  11.14  4.34     4.7     91.2
# 1  89.139999  11.37  4.22     4.7     91.2
# 2  89.330002  11.31  4.24     4.7     91.2
# 3  88.849998  11.00  4.22     4.7     91.2
# 4  89.250000  11.13  4.25     4.7     91.2

# %%
data.isna().sum()
# Out:
# Date        0
# Open        0
# Close       0
# SAR         1
# MACD        0
# RSI         8
# ATR        49
# MFI        29
# USDX        2
# VIX         0
# EFFR       35
# UNRATE      0
# UMSCENT     0
# dtype: int64

# %%
data.drop(data.index[:49], inplace=True)

# Reset index after dropping rows
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#          Date         Open        Close         SAR      MACD        RSI  \
# 0  15-03-2006  1297.479980  1303.020020  1245.73999  4.059285  63.124058
# 1  16-03-2006  1303.020020  1305.329956  1245.73999  4.826013  66.985742
# 2  17-03-2006  1305.329956  1307.250000  1245.73999  5.571365  81.354102
# 3  20-03-2006  1307.250000  1305.079956  1245.73999  6.122679  81.725270
# 4  21-03-2006  1305.079956  1297.229980  1245.73999  6.260491  68.291731
#
#          ATR        MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# 0  10.392993  56.832217  89.699997  11.35  4.47     4.7     88.9
# 1  10.051992  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2   9.988794  60.493283  88.919998  12.12  4.60     4.7     88.9
# 3   9.984795  60.708410  89.129997  11.79  4.55     4.7     88.9
# 4  10.033796  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
data.isna().sum()
# Out:
# Date        0
# Open        0
# Close       0
# SAR         0
# MACD        0
# RSI         0
# ATR         0
# MFI         0
# USDX        2
# VIX         0
# EFFR       35
# UNRATE      0
# UMSCENT     0
# dtype: int64

# %%
data = data.fillna(data.mean())
data.isna().sum()
# Out:
# Open       0
# Close      0
# SAR        0
# MACD       0
# RSI        0
# ATR        0
# MFI        0
# USDX       0
# VIX        0
# EFFR       0
# UNRATE     0
# UMSCENT    0
# dtype: int64

# %%
len(data)
# Out:
# 4397

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')
data['Date'] = data['Date'].dt.strftime('%Y-%m-%d')
data.set_index("Date",inplace=True)
data.head()
# Out:
#                    Open        Close         SAR      MACD        RSI  \
# Date
# 2006-03-15  1297.479980  1303.020020  1245.73999  4.059285  63.124058
# 2006-03-16  1303.020020  1305.329956  1245.73999  4.826013  66.985742
# 2006-03-17  1305.329956  1307.250000  1245.73999  5.571365  81.354102
# 2006-03-20  1307.250000  1305.079956  1245.73999  6.122679  81.725270
# 2006-03-21  1305.079956  1297.229980  1245.73999  6.260491  68.291731
#
#                   ATR        MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  10.392993  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  10.051992  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17   9.988794  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20   9.984795  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  10.033796  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
data.tail()
# Out:
#                    Open        Close         SAR       MACD        RSI  \
# Date
# 2023-08-25  4389.379883  4405.709961  666.789978  25.209702  35.991291
# 2023-08-28  4426.029785  4433.310059  666.789978  23.847631  49.174533
# 2023-08-29  4432.750000  4497.629883  666.789978  25.288242  65.226164
# 2023-08-30  4500.339844  4514.870117  666.789978  27.215893  74.945676
# 2023-08-31  4517.009766  4507.660156  666.789978  28.535526  73.285881
#
#                   ATR        MFI        USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2023-08-25  42.880645  43.533399  104.080002  15.68  5.33     3.8     69.5
# 2023-08-28  42.025645  43.221533  104.059998  15.08  5.33     3.8     69.5
# 2023-08-29  42.574238  42.832510  103.550003  14.45  5.33     3.8     69.5
# 2023-08-30  42.287441  42.280624  103.160004  13.88  5.33     3.8     69.5
# 2023-08-31  42.213437  45.671748  103.620003  13.57  5.33     3.8     69.5

# %% [markdown]
# ## Data Exploration

# %%
print("Column Names : ")
count=0
for column in data.columns:
    print(column)
    count+=1
print("Total no of columns in dataset = "+str(count))
# Out:
# Column Names :
# Open
# Close
# SAR
# MACD
# RSI
# ATR
# MFI
# USDX
# VIX
# EFFR
# UNRATE
# UMSCENT
# Total no of columns in dataset = 12

# %%
data.dtypes
# Out:
# Open       float64
# Close      float64
# SAR        float64
# MACD       float64
# RSI        float64
# ATR        float64
# MFI        float64
# USDX       float64
# VIX        float64
# EFFR       float64
# UNRATE     float64
# UMSCENT    float64
# dtype: object

# %%
data.describe()
# Out:
#               Open        Close          SAR         MACD          RSI  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean   2215.602655  2215.995963   989.352357     9.961819    55.994301
# std    1060.553331  1060.725848   404.539485    36.226028    19.770110
# min     679.280029   676.530029   666.789978  -212.441916     0.000000
# 25%    1340.199951  1340.199951   666.789978    -2.658452    42.061798
# 50%    1976.930054  1978.089966   666.789978    14.138794    56.496934
# 75%    2854.649902  2853.580078  1576.089966    25.995324    70.086803
# max    4804.509766  4796.560059  1576.089966   107.397605    99.566735
#
#                ATR          MFI         USDX          VIX         EFFR  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean     28.674883    53.891476    88.777090    19.870871     1.299982
# std      20.503058    10.139617     9.272771     9.110330     1.721908
# min       8.880007    22.365246    71.330002     9.140000     0.040000
# 25%      14.784806    46.742932    80.480003    13.740000     0.100000
# 50%      20.522988    53.825806    89.129997    17.500000     0.200000
# 75%      35.086426    61.071333    96.570000    23.110001     1.990000
# max     123.041602    89.979368   114.110001    82.690002     5.410000
#
#             UNRATE      UMSCENT
# count  4397.000000  4397.000000
# mean      6.016352    80.222766
# std       2.205442    13.047978
# min       3.400000    50.000000
# 25%       4.300000    70.600000
# 50%       5.100000    80.900000
# 75%       7.800000    91.900000
# max      14.700000   101.400000

# %%
df = data.copy()
len(df)
# Out:
# 4397

# %%
df.head()
# Out:
#                    Open        Close         SAR      MACD        RSI  \
# Date
# 2006-03-15  1297.479980  1303.020020  1245.73999  4.059285  63.124058
# 2006-03-16  1303.020020  1305.329956  1245.73999  4.826013  66.985742
# 2006-03-17  1305.329956  1307.250000  1245.73999  5.571365  81.354102
# 2006-03-20  1307.250000  1305.079956  1245.73999  6.122679  81.725270
# 2006-03-21  1305.079956  1297.229980  1245.73999  6.260491  68.291731
#
#                   ATR        MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  10.392993  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  10.051992  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17   9.988794  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20   9.984795  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  10.033796  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
close = df['Close']

fig = plt.figure(figsize=(10,5))
fig.set(facecolor = "white")
plt.plot(close, 'mediumblue',label=['S&P 500 Close Price'])
plt.gca().set_xticklabels([])
plt.grid(False)

plt.title('Stock Price GSPC')
plt.xlabel('Time (years)')
plt.ylabel('Close price')
plt.show()

# %%
df['MA_50'] = df['Close'].rolling(50).mean()
df['MA_200'] = df['Close'].rolling(200).mean()

fig = plt.figure(figsize=(10,5))
fig.set(facecolor = "white")
plt.plot(df['Close'], 'mediumblue',label=['S&P 500 Close Price'])
plt.plot(df['MA_50'],'red', label=['50-day MA'])
plt.plot(df['MA_200'],'green', label=['200-day MA'])
plt.legend(['S&P 500 Close Price', '50-day Moving Average', '200-day Moving Average'], loc='upper left')

plt.gca().set_xticklabels([])
plt.grid(False)

plt.title('Stock Price GSPC')
plt.xlabel('Time (years)')
plt.ylabel('Close price')
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
data.head()
# Out:
#                    Open        Close         SAR      MACD        RSI  \
# Date
# 2006-03-15  1297.479980  1303.020020  1245.73999  4.059285  63.124058
# 2006-03-16  1303.020020  1305.329956  1245.73999  4.826013  66.985742
# 2006-03-17  1305.329956  1307.250000  1245.73999  5.571365  81.354102
# 2006-03-20  1307.250000  1305.079956  1245.73999  6.122679  81.725270
# 2006-03-21  1305.079956  1297.229980  1245.73999  6.260491  68.291731
#
#                   ATR        MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  10.392993  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  10.051992  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17   9.988794  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20   9.984795  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  10.033796  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
fig = plt.figure(figsize= (10,5))
sns.heatmap(data.corr(), annot=True)
sns.set_style("whitegrid")
plt.show()

# %%
data = data.iloc[:, 1:]
fig = plt.figure(figsize= (10,5))
sns.heatmap(data.corr(), annot=True)
sns.set_style("whitegrid")
plt.show()

# %%
fig = plt.figure(figsize = (20, 12))
data.plot(subplots = True, figsize = (12,10),grid=False)
sns.set_style("whitegrid")
plt.show()

# %%
data.describe()
# Out:
#              Close          SAR         MACD          RSI          ATR  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean   2215.995963   989.352357     9.961819    55.994301    28.674883
# std    1060.725848   404.539485    36.226028    19.770110    20.503058
# min     676.530029   666.789978  -212.441916     0.000000     8.880007
# 25%    1340.199951   666.789978    -2.658452    42.061798    14.784806
# 50%    1978.089966   666.789978    14.138794    56.496934    20.522988
# 75%    2853.580078  1576.089966    25.995324    70.086803    35.086426
# max    4796.560059  1576.089966   107.397605    99.566735   123.041602
#
#                MFI         USDX          VIX         EFFR       UNRATE  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean     53.891476    88.777090    19.870871     1.299982     6.016352
# std      10.139617     9.272771     9.110330     1.721908     2.205442
# min      22.365246    71.330002     9.140000     0.040000     3.400000
# 25%      46.742932    80.480003    13.740000     0.100000     4.300000
# 50%      53.825806    89.129997    17.500000     0.200000     5.100000
# 75%      61.071333    96.570000    23.110001     1.990000     7.800000
# max      89.979368   114.110001    82.690002     5.410000    14.700000
#
#            UMSCENT
# count  4397.000000
# mean     80.222766
# std      13.047978
# min      50.000000
# 25%      70.600000
# 50%      80.900000
# 75%      91.900000
# max     101.400000

# %% [markdown]
# ## Data Denoising

# %%
data.head()
# Out:
#                   Close         SAR      MACD        RSI        ATR  \
# Date
# 2006-03-15  1303.020020  1245.73999  4.059285  63.124058  10.392993
# 2006-03-16  1305.329956  1245.73999  4.826013  66.985742  10.051992
# 2006-03-17  1307.250000  1245.73999  5.571365  81.354102   9.988794
# 2006-03-20  1305.079956  1245.73999  6.122679  81.725270   9.984795
# 2006-03-21  1297.229980  1245.73999  6.260491  68.291731  10.033796
#
#                   MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
from skimage.restoration import (denoise_wavelet, estimate_sigma)

data['Close']= denoise_wavelet(data.iloc[:, 0], wavelet='haar',
                                      #method='BayesShrink',
                                      method='VisuShrink',
                                      mode='soft', rescale_sigma = True)
data.head()
# Out:
#                   Close         SAR      MACD        RSI        ATR  \
# Date
# 2006-03-15  1297.479562  1245.73999  4.059285  63.124058  10.392993
# 2006-03-16  1297.479562  1245.73999  4.826013  66.985742  10.051992
# 2006-03-17  1297.479562  1245.73999  5.571365  81.354102   9.988794
# 2006-03-20  1297.479562  1245.73999  6.122679  81.725270   9.984795
# 2006-03-21  1297.479562  1245.73999  6.260491  68.291731  10.033796
#
#                   MFI       USDX    VIX  EFFR  UNRATE  UMSCENT
# Date
# 2006-03-15  56.832217  89.699997  11.35  4.47     4.7     88.9
# 2006-03-16  56.670295  89.070000  11.98  4.55     4.7     88.9
# 2006-03-17  60.493283  88.919998  12.12  4.60     4.7     88.9
# 2006-03-20  60.708410  89.129997  11.79  4.55     4.7     88.9
# 2006-03-21  60.639310  89.620003  11.62  4.54     4.7     88.9

# %%
data.describe()
# Out:
#              Close          SAR         MACD          RSI          ATR  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean   2216.078954   989.352357     9.961819    55.994301    28.674883
# std    1059.511080   404.539485    36.226028    19.770110    20.503058
# min     728.323895   666.789978  -212.441916     0.000000     8.880007
# 25%    1346.052412   666.789978    -2.658452    42.061798    14.784806
# 50%    1971.031453   666.789978    14.138794    56.496934    20.522988
# 75%    2842.568211  1576.089966    25.995324    70.086803    35.086426
# max    4748.140636  1576.089966   107.397605    99.566735   123.041602
#
#                MFI         USDX          VIX         EFFR       UNRATE  \
# count  4397.000000  4397.000000  4397.000000  4397.000000  4397.000000
# mean     53.891476    88.777090    19.870871     1.299982     6.016352
# std      10.139617     9.272771     9.110330     1.721908     2.205442
# min      22.365246    71.330002     9.140000     0.040000     3.400000
# 25%      46.742932    80.480003    13.740000     0.100000     4.300000
# 50%      53.825806    89.129997    17.500000     0.200000     5.100000
# 75%      61.071333    96.570000    23.110001     1.990000     7.800000
# max      89.979368   114.110001    82.690002     5.410000    14.700000
#
#            UMSCENT
# count  4397.000000
# mean     80.222766
# std      13.047978
# min      50.000000
# 25%      70.600000
# 50%      80.900000
# 75%      91.900000
# max     101.400000

# %% [markdown]
# ## Evaluation Metrics

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return (np.mean(np.abs((y_true - y_pred)/(y_true))*100))

def calculate_scores(y_true, y_pred):
  mae = mean_absolute_error(y_true, y_pred)
  mape = mean_absolute_percentage_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  R = np.corrcoef(y_true, y_pred)
  r2 = r2_score(y_true, y_pred)

  print(f"Mean Absolute Error (MAE): {mae:.4f}")
  print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
  print(f"Mean Squared Error (MSE): {mse:.4f}")
  print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
  print(f"R-Pearson Correlation Coefficient (R): {R[0,1]:.4f}")
  print(f"R-squared (R2): {r2:.4f}")
  dic = {'rmse':rmse, 'R': R[0,1], 'mape': mape}
  return (dic)

# %% [markdown]
# ## Supporting Function

# %%
def DatasetCreation(dataset, time_step = 1):  ##defining a function that gives a dataset and a time step, which then returns the input and output data
   DataX, DataY = [], []
   for i in range(len(dataset)- time_step -1):
         a = dataset[i:(i+ time_step), ]
         DataX.append(a)
         DataY.append(dataset[i + time_step, 0]) #ydata consists close price
   return np.array(DataX), np.array(DataY)


def data_split(data, split = 0.2):
  #======= creating training and test data===#
  l1   = int(len(data) * (1- split))
  l2    = len(data) - l1
  data1  = data.iloc[0:l1,:]
  data2   = data.iloc[l1:len(data),:]
  return data1, data2

def min_max_transform(data, feature_range=(0, 1)):
   scaler = MinMaxScaler(feature_range)
   return scaler.fit_transform(data)

def min_max_inverse_transform(data_scaled, min_original, max_original):
    return min_original +  data_scaled*(max_original - min_original)

# %% [markdown]
# ## Visualization

# %%
def true_pred_plot(model_output):

  y_train = model_output['datasets']['y_train']
  y_test =  model_output['datasets']['y_test']

  train_pred = model_output['best_model']['train_predictions']
  test_pred = model_output['best_model']['test_predictions']

  ##====== Visualizing true vs predicted plots ========#
  fig = plt.figure(figsize= (14,5))
  plt.subplot(121)
  plt.scatter(y_train, train_pred, marker= "+", color = 'mediumblue')
  identity_line = np.linspace(max(min(y_train), min(train_pred)), min(max(y_train), max(train_pred)))
  plt.plot(identity_line, identity_line, color="red", linestyle="dashed", linewidth= 2.5)
  plt.xlabel("True")
  plt.ylabel("Predicted")
  plt.title("Training data (a)")

  plt.subplot(122)
  plt.scatter(y_test, test_pred, marker = "+", color = 'mediumblue')
  identity_line = np.linspace(max(min(y_test), min(test_pred)), min(max(y_test), max(test_pred)))
  plt.plot(identity_line, identity_line, color="red", linestyle="dashed", linewidth= 2.5)
  plt.xlabel("True")
  plt.ylabel("Predicted")
  plt.title("Test data (b)")

  plt.suptitle("Scatter plot of True vs Predicted Close prices")
  plt.show()


def best_model_prediction_plot(model_output):

  time_step =  model_output['hyper_parameters']['time_step']

  data = model_output['datasets']['data']

  train_predict_plot_data = np.empty_like(data.values[:,0])# extracting closing price
  train_predict_plot_data[:] = np.nan

  test_predict_plot_data = np.empty_like(data.values[:,0])
  test_predict_plot_data[:] = np.nan

  fig = plt.figure(figsize = (14,5))

  plt.subplot(121)

  train_pred = model_output['best_model']['train_predictions']
  test_pred = model_output['best_model']['test_predictions']

  train_predict_plot_data[time_step:len(train_pred)+ time_step] =  train_pred
  test_predict_plot_data[len(train_pred)+(time_step*2)+1:len(data.values)-1] = test_pred

  plt.plot(data.values[:,0],'k', linewidth = 1.5)
  plt.plot(train_predict_plot_data,'mediumblue',linewidth = 1.5)
  plt.plot(test_predict_plot_data,'darkgreen',linewidth = 1.5)
  plt.xlabel('')
  plt.ylabel('Close price')
  plt.title("(a)")
  plt.legend(['True value', 'Predicted value in train set', 'Predicted value in test set'], loc = 'upper left')

  plt.subplot(122)
  plt.plot(data.values[len(train_pred)+(time_step*2)+1:-1, 0],'k',linewidth = 1.5)
  plt.plot(test_pred,'darkgreen',linewidth = 1.5)
  plt.xlabel('')
  plt.ylabel('Close price')
  plt.title("(b)")
  plt.legend(['True value', 'Predicted value'], loc='upper left')

# %%
def create_visualization(model_output):
  true_pred_plot(model_output)
  best_model_prediction_plot(model_output)

# %% [markdown]
# ## Single Layer LSTM

# %%
from keras.optimizers import Adam,Adagrad,Nadam

def build_single_layer_LSTM(layers, time_step, num_features, optimizer = 0, learning_rate = 0.001, verbose = 1):
  model = Sequential()

  model.add(LSTM(int(layers[0]), input_shape = (time_step, num_features)))
  model.add(Dense(1, activation = 'linear'))

  optimizer = int(optimizer)

  if optimizer == 0:
    opt = Adam(learning_rate = learning_rate)
  elif optimizer == 1:
    opt = Adagrad(learning_rate = learning_rate)
  elif optimizer == 2:
    opt = Nadam(learning_rate = learning_rate)
  else:
    print("No optimizer found in the list(['Adam', 'Adagrad','Nadam'])!")

  model.compile(loss='mean_squared_error', optimizer= opt)

  if verbose == 1:
    print(model.summary())
  return model

# %%
optimizers_names = [0,1,2]

build_single_layer_LSTM([250], 5, 10, optimizers_names[2], 0.001, 1)
# Out:
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250)               261000
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 261251 (1020.51 KB)
# Trainable params: 261251 (1020.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
def single_layer_LSTM(neurons, hyper_parameters, data, time_step = 5, test_split = 0.2, epochs = 20,  num_replicates = 2):

  print("Progress: Performing data preparation steps.......\n")

  train_data, test_data = data_split(data, test_split)
  num_features = train_data.shape[1]

  min_train, max_train  = train_data["Close"].min(), train_data["Close"].max()
  min_test, max_test   =  test_data["Close"].min(), test_data["Close"].max()

  train_data_scaled  =  min_max_transform(train_data)
  test_data_scaled   = min_max_transform(test_data)

  X_train, y_train  =   DatasetCreation(train_data_scaled, time_step)
  X_test, y_test    =   DatasetCreation(test_data_scaled, time_step)

  y_train_original  =  min_max_inverse_transform(y_train, min_train, max_train)
  y_test_original  =  min_max_inverse_transform(y_test, min_test, max_test)

  print("Progress: Building and training models.......\n")

  neurons = np.array(neurons)
  #============ arrays for collecting test scores ================#
  rmse_array = np.zeros((len(neurons), num_replicates))
  #mae_array  = np.zeros((len(neurons), num_replicates))
  mape_array = np.zeros((len(neurons), num_replicates))
  #R2_array   = np.zeros((len(neurons), num_replicates))
  R_array    = np.zeros((len(neurons), num_replicates))
  elapsed_time_array = np.zeros((len(neurons), num_replicates))

  #========== array for collecting history and predictions =======#
  models_history = []

  train_predictions = []
  test_predictions  = []

  for i in range(len(neurons)):

    print("Model hyperparameters used: \n ", hyper_parameters[i])
    model_history_per_replicate = []
    train_predictions_per_replicate = []
    test_predictions_per_replicate  = []

    hidden_nodes = int(neurons[i])

    for k in range(num_replicates):

      print("Program is running for %d neurons and %d replicate ----->\n" %(hidden_nodes, k))

      layers = [hidden_nodes]

      model = build_single_layer_LSTM(layers, time_step, num_features, optimizer = hyper_parameters[i][0], learning_rate = hyper_parameters[i][1], verbose = 0)
      callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)

      start = time.time()
      history = model.fit(X_train, y_train, batch_size = hyper_parameters[i][2], epochs= epochs, callbacks=[callback], verbose = 1)

      end = time.time()
      elapsed_time = end - start

      model_history_per_replicate.append(history)

      train_pred   =  min_max_inverse_transform(model.predict(X_train).ravel(), min_train, max_train)
      test_pred    =  min_max_inverse_transform(model.predict(X_test).ravel(), min_test, max_test)

      train_predictions_per_replicate.append(train_pred)
      test_predictions_per_replicate.append(test_pred)

      scores =   calculate_scores(min_max_inverse_transform(y_test, min_test, max_test),test_pred)

      rmse_array[i][k] = scores['rmse']
      mape_array[i][k] =  scores['mape']
      R_array[i][k] = scores['R']
      elapsed_time_array[i][k] = elapsed_time

    models_history.append(model_history_per_replicate)
    train_predictions.append(train_predictions_per_replicate)
    test_predictions.append(test_predictions_per_replicate)

  print("Progress: Collecting outputs.......\n")


  neurons_df = pd.DataFrame(neurons)
  rmse_df = pd.DataFrame(rmse_array)
  #mae_df  = pd.DataFrame(mae_array)
  mape_df  = pd.DataFrame(mape_array)
  #R2_df   = pd.DataFrame(R2_array)
  R_df    = pd.DataFrame(R_array)
  elapsed_time_df =  pd.DataFrame(elapsed_time_array)

  train_predictions  = np.array(train_predictions)
  test_predictions   = np.array(test_predictions)

  #==== Idendifying  the best model results based on rmse ===============#
  min_index = pd.DataFrame(rmse_df.min(axis = 1)).idxmin()[0]
  min_col =   pd.DataFrame(rmse_df.min(axis = 0)).idxmin()[0]

  num_neurons_with_best_rmse = neurons_df.loc[min_index,0]

  best_rmse = rmse_df.loc[min_index, min_col]
  #mae_with_best_rmse = mae_df.loc[min_index, min_col]
  mape_with_best_rmse = mape_df.loc[min_index, min_col]
  #R2_with_best_rmse = R2_df.loc[min_index, min_col]
  R_with_best_rmse =  R_df.loc[min_index, min_col]
  elapsed_time_with_best_rmse = elapsed_time_df.loc[min_index, min_col]

  train_predictions_with_best_rmse = train_predictions[min_index][min_col]
  test_predictions_with_best_rmse = test_predictions[min_index][min_col]

  loss_with_best_rmse = models_history[min_index][min_col].history['loss']
  #val_loss_with_best_rmse = models_history[min_index][min_col].history['val_loss']

  #======= Collecting hyperparameters=============#
  hyper_parameters = { 'neurons': neurons,
                       'model_specific_hyper_parameters': hyper_parameters,#additional best_hyper_parmeters for each models
                       'epochs': epochs,
                       'time_step':time_step,
                       'num_replicates': num_replicates,
                       'test_split':test_split
                        }
  #======= Collecting test scores =============#
  scores = {'neurons': neurons_df, 'rmse': rmse_df, 'mape': mape_df, 'R': R_df, 'elapsed_time': elapsed_time_df}

  #======= Collecting average test scores =============#
  avg_scores = pd.DataFrame({'neurons': neurons,
                            'rmse': rmse_df.mean(axis = 1),
                            'mape': mape_df.mean(axis = 1),
                            'R': R_df.mean(axis = 1),
                            'elapsed_time': elapsed_time_df.mean(axis = 1)})

 #======= Collecting average test scores =============#
  all_stds = pd.DataFrame({'neurons': neurons,
                            'rmse': rmse_df.std(axis = 1),
                            'mape': mape_df.std(axis = 1),
                            'R': R_df.std(axis = 1),
                            'elapsed_time': elapsed_time_df.std(axis = 1)})


 #======= Collecting average test scores =============#
  all_minimums = pd.DataFrame({'neurons': neurons,
                            'rmse': rmse_df.min(axis = 1),
                            'mape': mape_df.min(axis = 1),
                            'R': R_df.min(axis = 1),
                            'elapsed_time': elapsed_time_df.min(axis = 1)})

  #======= Collecting average test scores =============#
  all_maximums = pd.DataFrame({'neurons': neurons,
                            'rmse': rmse_df.max(axis = 1),
                            'mape': mape_df.max(axis = 1),
                            'R': R_df.max(axis = 1),
                            'elapsed_time': elapsed_time_df.max(axis = 1)})



  #======= Collecting the best model results =============#
  model_with_best_rmse = {  'neurons': num_neurons_with_best_rmse,
                            'replicate': min_col,
                            'rmse': best_rmse,
                            'mape': mape_with_best_rmse,
                            'R':  R_with_best_rmse,
                            'elapsed_time': elapsed_time_with_best_rmse,
                            'train_predictions':train_predictions_with_best_rmse,
                            'test_predictions': test_predictions_with_best_rmse,
                            'loss':loss_with_best_rmse,

                         }

  datasets  =    {'data': data,
                  'X_train': X_train,
                  'X_test': X_test,
                  'y_train': y_train_original,
                  'y_test': y_test_original
                  }


  print("\nProgress: All works are done successfully, congratulations!!\n")

  print("\nBest model (neurons, replicate, rmse): ", num_neurons_with_best_rmse, min_col, best_rmse)
  print('\nAverage scores:\n', avg_scores)
  print('\nStandard_deviations:\n', all_stds)
  print('\nMinimums:\n', all_minimums)
  print('\nMaximums:\n', all_maximums)

  #======= Collecting all the outputs together =============#
  output_dictionary = { 'hyper_parameters': hyper_parameters,
                        'best_model': model_with_best_rmse,
                        'scores': scores,
                        'avg_scores': avg_scores,
                        'all_stds': all_stds,
                        'all_minimums': all_minimums,
                        'all_maximums': all_maximums,
                        'train_predictions': train_predictions,
                        'test_predictions':  test_predictions,
                        'models_history': models_history,
                        'datasets': datasets
                       }

  return (output_dictionary)

# %% [markdown]
# ## ARO

# %%
# !pip install mealpy
# Out:
# Requirement already satisfied: mealpy in c:\users\abdur\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\abdur\anaconda3\lib\site-packages (from mealpy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\abdur\anaconda3\lib\site-packages (from mealpy) (3.7.2)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\abdur\anaconda3\lib\site-packages (from mealpy) (1.11.1)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\abdur\anaconda3\lib\site-packages (from mealpy) (2.0.3)
# Requirement already satisfied: opfunu>=1.0.0 in c:\users\abdur\anaconda3\lib\site-packages (from mealpy) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdur\anaconda3\lib\site-packages (from matplotlib>=3.3.0->mealpy) (2.8.2)
# Requirement already satisfied: requests>=2.27.0 in c:\users\abdur\anaconda3\lib\site-packages (from opfunu>=1.0.0->mealpy) (2.31.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdur\anaconda3\lib\site-packages (from pandas>=1.2.0->mealpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abdur\anaconda3\lib\site-packages (from pandas>=1.2.0->mealpy) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\abdur\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdur\anaconda3\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdur\anaconda3\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdur\anaconda3\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdur\anaconda3\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2023.7.22)

# %%
from keras.optimizers import Adam,Adagrad
import mealpy
mealpy.__version__
from mealpy import FloatVar, ARO, StringVar, IntegerVar

# %%
train_data ,test_data  = data_split(data, 0.2)
print("Total train data : ")
print(len(train_data))
print("No of data used for hyper-parametr tuning")
train_data ,val_data  = data_split(train_data, 0.2)
print("training data : ")
print(len(train_data))
print("validation data : ")
print(len(val_data))
# Out:
# Total train data :
# 3517
# No of data used for hyper-parametr tuning
# training data :
# 2813
# validation data :
# 704

# %%
# Scaling data
min_train, max_train = train_data["Close"].min(), train_data["Close"].max()
min_test, max_test = val_data["Close"].min(), val_data["Close"].max()
train_data_scaled = min_max_transform(train_data)
test_data_scaled = min_max_transform(val_data)

# Creating input and output datasets for LSTM
X_train, y_train = DatasetCreation(train_data_scaled, 5)
X_test, y_test = DatasetCreation(test_data_scaled, 5)

num_features = train_data.shape[1]

# Inverting scaled target data to original scale
y_train_original = min_max_inverse_transform(y_train, min_train, max_train)
y_test_original = min_max_inverse_transform(y_test, min_test, max_test)

# %% [markdown]
# # ARO Epoch - 15, Population - 25

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=15, pop_size=25) #epoch = 15 , population size - 25

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam")
print("Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch):", best_hyperparameters.solution)
# Out:
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 142
# 2.0
# 0.05403689100664387
# 14
# 22/22 [==============================] - 1s 4ms/step
# 2023/12/30 07:05:05 PM, INFO, mealpy.swarm_based.ARO.IARO: Solving single objective optimization problem.
# Root Mean Squared Error (RMSE): 253.5249
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 36
# 1.0
# 0.007388256129342279
# 21
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 71.7842
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 135
# 0.0
# 0.05640383815074323
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 45.3218
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 107
# 1.0
# 0.03623992978563459
# 28
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.7796
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 90
# 1.0
# 0.028541924576397336
# 30
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 27.6196
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 59
# 1.0
# 0.02051300989628387
# 20
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 34.4388
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 22
# 1.0
# 0.07408588842912162
# 27
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 36.8480
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 159
# 2.0
# 0.010614573284068403
# 14
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.9246
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 46
# 1.0
# 0.07338917120212685
# 27
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.5672
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 189
# 2.0
# 0.014618537724552912
# 12
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 22.1610
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 100
# 2.0
# 0.09433605627776973
# 19
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.6317
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 180
# 1.0
# 0.04479138285702636
# 29
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 24.3080
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 104
# 0.0
# 0.018677624466297726
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.5717
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 173
# 2.0
# 0.017817685802075912
# 21
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.8855
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 198
# 2.0
# 0.09415170933354879
# 23
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 305.0060
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 90
# 0.0
# 0.09423205176435898
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 31.3704
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 60
# 0.0
# 0.041096007698206934
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 43.6779
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 62
# 1.0
# 0.06628338079390558
# 25
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.2976
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 39
# 1.0
# 0.05536021643258112
# 17
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.2456
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 156
# 2.0
# 0.07735523744509451
# 20
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 27.2346
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 169
# 0.0
# 0.09585743582435798
# 17
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 265.0078
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 117
# 2.0
# 0.07011357449765543
# 10
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 26.2134
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 158
# 0.0
# 0.08193542076436929
# 16
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 88.3146
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 1.0
# 0.029448059747362754
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.4743
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 14
# 0.0
# 0.08396294435361376
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 45.5242
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 99
# 2.0
# 0.04578762832085864
# 25
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.0964
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.1
# 10
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 228.1900
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 188
# 2.0
# 0.001
# 17
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 25.4502
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 107
# 1.0
# 0.03623992978563459
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.9102
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
#
("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [1.0000000e+01 0.0000000e+00 4.9402527e-03 8.0000000e+00]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 10
# Optimizer : 0
# Learning Rate : 0.0049
# Batch Size : 8

# %% [markdown]
# ## Predicting values using LSTM-ARO

# %%
if optimizer == 0:
  opt = 'Adam'
elif optimizer == 1:
  opt = 'Adagrad',
elif optimizer == 2:
  opt = 'Nadam'
else:
  print("No optimizer found in the list(['Adam', 'Adagrad','Nadam'])!")

print("Neurons : " + str(neurons))
print("Optimizer : " + str(opt))
print("Learning Rate : " + str(learning_rate))
print("Batch Size : " + str(batch_size))
# Out:
# Neurons : 10
# Optimizer : Adam
# Learning Rate : 0.0049
# Batch Size : 8

# %%
neurons = np.array([neurons])

best_hyper_parameters = [[optimizer, learning_rate, batch_size]]

sl_model_output = single_layer_LSTM(neurons, best_hyper_parameters, data, time_step = 5, test_split = 0.2,
                          epochs = 100, num_replicates = 30)

#epoch = 100 , replicates = 30
# Out:
# Progress: Performing data preparation steps.......
#
# Progress: Building and training models.......
#
# Model hyperparameters used:
#   [0, 0.0049, 8]
# Program is running for 10 neurons and 0 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 5ms/step - loss: 0.0082
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.1619e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.3306e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.7407e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.3566e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1918e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.6724e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.6655e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.8187e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0310e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.1178e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.8814e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.9258e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 49.5783
# Mean Absolute Percentage Error (MAPE): 1.2786
# Mean Squared Error (MSE): 4518.2934
# Root Mean Squared Error (RMSE): 67.2183
# R-Pearson Correlation Coefficient (R): 0.9935
# R-squared (R2): 0.9821
# Program is running for 10 neurons and 1 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0035
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.2393e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.5584e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.4426e-05
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.2295e-05
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.3572e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9428e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.3657e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.3810e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.7617e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.8079e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0036e-04
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6808e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3285e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9339e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9260e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0307e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4626e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3690e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8416e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 38.5530
# Mean Absolute Percentage Error (MAPE): 0.9929
# Mean Squared Error (MSE): 2523.4398
# Root Mean Squared Error (RMSE): 50.2339
# R-Pearson Correlation Coefficient (R): 0.9964
# R-squared (R2): 0.9900
# Program is running for 10 neurons and 2 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0049
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.2745e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.1941e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.7556e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1333e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0330e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1821e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1743e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.2802e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.2180e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2391e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.3033e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5223e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.8438e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.4862e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5327e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.2484e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3274e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.7217e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.7768e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6271e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.0569e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.4150e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.2726e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 28.4141
# Mean Absolute Percentage Error (MAPE): 0.7472
# Mean Squared Error (MSE): 1721.0834
# Root Mean Squared Error (RMSE): 41.4859
# R-Pearson Correlation Coefficient (R): 0.9970
# R-squared (R2): 0.9932
# Program is running for 10 neurons and 3 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0073
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.8647e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.8704e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.4650e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0687e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0543e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0614e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.6483e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.7399e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9556e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.3886e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.0837e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2228e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.4801e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9389e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7709e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.1334e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2589e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.7650e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.4761e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6776e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6633e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2137e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8142e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9330e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4877e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9005e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9661e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2742e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5634e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5687e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2711e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 30.7028
# Mean Absolute Percentage Error (MAPE): 0.8036
# Mean Squared Error (MSE): 1944.5254
# Root Mean Squared Error (RMSE): 44.0968
# R-Pearson Correlation Coefficient (R): 0.9970
# R-squared (R2): 0.9923
# Program is running for 10 neurons and 4 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 6ms/step - loss: 0.0023
# Epoch 2/100
# 439/439 [==============================] - 2s 6ms/step - loss: 2.3817e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2141e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 6ms/step - loss: 9.1866e-05
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.8496e-05
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.5195e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.0212e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.4961e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.9653e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.7529e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0689e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6080e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2492e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6029e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2879e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.1162e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3713e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.7849e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5749e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4578e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2163e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.9133e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8433e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 31.7481
# Mean Absolute Percentage Error (MAPE): 0.8310
# Mean Squared Error (MSE): 2196.8826
# Root Mean Squared Error (RMSE): 46.8709
# R-Pearson Correlation Coefficient (R): 0.9956
# R-squared (R2): 0.9913
# Program is running for 10 neurons and 5 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0041
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.1386e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.7601e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1793e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2850e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.9734e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.1048e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2376e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.3625e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6640e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 6ms/step - loss: 7.9887e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1523e-04
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6269e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.2192e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 6ms/step - loss: 7.6019e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.9679e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.1842e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8758e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3032e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.9799e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0137e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.6570e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9512e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9784e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.5786e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4943e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.1985e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.6956e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1772e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4349e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1489e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3321e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 29.4829
# Mean Absolute Percentage Error (MAPE): 0.7883
# Mean Squared Error (MSE): 1954.4383
# Root Mean Squared Error (RMSE): 44.2090
# R-Pearson Correlation Coefficient (R): 0.9965
# R-squared (R2): 0.9922
# Program is running for 10 neurons and 6 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0045
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.3553e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.5128e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0598e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2117e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.6556e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.0332e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0485e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.5367e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.7166e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.7168e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5296e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.6030e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4967e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.5085e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7338e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8104e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5619e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.6863e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2686e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.5266e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.7501e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6267e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4654e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9398e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.4876e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.8410e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6085e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4536e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8750e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8206e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9811e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4903e-05
# Epoch 34/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.8034e-05
# Epoch 35/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.5038e-05
# Epoch 36/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2306e-05
# Epoch 37/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2557e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 26.7641
# Mean Absolute Percentage Error (MAPE): 0.7128
# Mean Squared Error (MSE): 1567.7731
# Root Mean Squared Error (RMSE): 39.5951
# R-Pearson Correlation Coefficient (R): 0.9972
# R-squared (R2): 0.9938
# Program is running for 10 neurons and 7 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0013
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.0325e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1112e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0051e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1296e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.5596e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.9518e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.7841e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5683e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9063e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.8590e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.3869e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0808e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.6140e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6522e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6607e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.0365e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.5729e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 33.0459
# Mean Absolute Percentage Error (MAPE): 0.8709
# Mean Squared Error (MSE): 2189.7038
# Root Mean Squared Error (RMSE): 46.7943
# R-Pearson Correlation Coefficient (R): 0.9966
# R-squared (R2): 0.9913
# Program is running for 10 neurons and 8 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0030
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.7074e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.6871e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1012e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2398e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0150e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.0249e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0027e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2698e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7357e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.3788e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.4145e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6334e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9023e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.6896e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.1937e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8471e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3581e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4834e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5366e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3238e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0175e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2872e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4098e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9292e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8270e-05
# Epoch 27/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.6410e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 6ms/step - loss: 3.3587e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 6ms/step - loss: 4.8733e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3710e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1698e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5877e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2601e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 30.3102
# Mean Absolute Percentage Error (MAPE): 0.7959
# Mean Squared Error (MSE): 1715.2064
# Root Mean Squared Error (RMSE): 41.4151
# R-Pearson Correlation Coefficient (R): 0.9974
# R-squared (R2): 0.9932
# Program is running for 10 neurons and 9 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0055
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.5737e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.6210e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1256e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2943e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2246e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0611e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.3084e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.1500e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.9014e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.9478e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.8678e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2730e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.9976e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.4586e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0898e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4175e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4663e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2016e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.9881e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8861e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3774e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5154e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0046e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2141e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 29.4327
# Mean Absolute Percentage Error (MAPE): 0.7926
# Mean Squared Error (MSE): 2352.0633
# Root Mean Squared Error (RMSE): 48.4981
# R-Pearson Correlation Coefficient (R): 0.9957
# R-squared (R2): 0.9907
# Program is running for 10 neurons and 10 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0028
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.4920e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.5783e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1045e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1494e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.3765e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.6358e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.1651e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5584e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.8880e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0539e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.5862e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9591e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3639e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.9412e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.0744e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.0273e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8315e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4377e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.3564e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.9794e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0775e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8861e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.2963e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3674e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.1654e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0814e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1787e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1147e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.1853e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0552e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 33.5296
# Mean Absolute Percentage Error (MAPE): 0.8698
# Mean Squared Error (MSE): 2082.8608
# Root Mean Squared Error (RMSE): 45.6384
# R-Pearson Correlation Coefficient (R): 0.9972
# R-squared (R2): 0.9917
# Program is running for 10 neurons and 11 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 5ms/step - loss: 0.0038
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.7229e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.3295e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0850e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.5357e-05
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.5365e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2961e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.2293e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.7090e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2432e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.6201e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.3906e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2009e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6968e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0587e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.8444e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5744e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2799e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8936e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.9532e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.4325e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7791e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6618e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6470e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1776e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0522e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6276e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1486e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.1758e-05
# Epoch 30/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.5015e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 6ms/step - loss: 5.0210e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 6ms/step - loss: 4.4044e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2561e-05
# Epoch 34/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.6959e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 23.4799
# Mean Absolute Percentage Error (MAPE): 0.6299
# Mean Squared Error (MSE): 1452.3241
# Root Mean Squared Error (RMSE): 38.1094
# R-Pearson Correlation Coefficient (R): 0.9972
# R-squared (R2): 0.9942
# Program is running for 10 neurons and 12 replicate ----->
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0019
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.5281e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2104e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1302e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0495e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.5000e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.7512e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.7714e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.4985e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4114e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9439e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.3376e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2454e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2784e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.1766e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0175e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.8283e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1869e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.9721e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.0146e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8522e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0832e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.9975e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3416e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6543e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0716e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2172e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7021e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.0869e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.9538e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.8276e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.5845e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.2776e-05
# Epoch 34/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.9882e-05
# Epoch 35/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.0500e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 25.1963
# Mean Absolute Percentage Error (MAPE): 0.6714
# Mean Squared Error (MSE): 1497.5035
# Root Mean Squared Error (RMSE): 38.6976
# R-Pearson Correlation Coefficient (R): 0.9972
# R-squared (R2): 0.9941
# Program is running for 10 neurons and 13 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 6s 5ms/step - loss: 0.0015
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.7372e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2817e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0874e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.9242e-05
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.1229e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.2316e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.7284e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.8227e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.9982e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2384e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9271e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.4875e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8287e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.0085e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.9718e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6869e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.0172e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6352e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 34.4346
# Mean Absolute Percentage Error (MAPE): 0.8831
# Mean Squared Error (MSE): 2106.6457
# Root Mean Squared Error (RMSE): 45.8982
# R-Pearson Correlation Coefficient (R): 0.9967
# R-squared (R2): 0.9916
# Program is running for 10 neurons and 14 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 5ms/step - loss: 0.0025
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.1032e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2323e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.3513e-05
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.9236e-05
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.0156e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.9317e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.6342e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.3137e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.5100e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5480e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.8585e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2815e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7472e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4756e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3689e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.0554e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.9832e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7923e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3681e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4339e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3929e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 48.0984
# Mean Absolute Percentage Error (MAPE): 1.2385
# Mean Squared Error (MSE): 3479.4695
# Root Mean Squared Error (RMSE): 58.9870
# R-Pearson Correlation Coefficient (R): 0.9957
# R-squared (R2): 0.9862
# Program is running for 10 neurons and 15 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0036
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.4382e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.3686e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0628e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0084e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0012e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1930e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.1122e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.3354e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.1292e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.3990e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.0675e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.9398e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9169e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2269e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.9618e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.4797e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.0742e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7124e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.1382e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4601e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0060e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8142e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.7876e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.0126e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.2464e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6831e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8635e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.3041e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5551e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8182e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 25.9951
# Mean Absolute Percentage Error (MAPE): 0.6857
# Mean Squared Error (MSE): 1702.0308
# Root Mean Squared Error (RMSE): 41.2557
# R-Pearson Correlation Coefficient (R): 0.9969
# R-squared (R2): 0.9932
# Program is running for 10 neurons and 16 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0045
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.9547e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.9599e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.6123e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0546e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.1967e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.0319e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.1075e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.2951e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.7703e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4755e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.9079e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.7844e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.3599e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.5197e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7896e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0513e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.8429e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3558e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.1751e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1483e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.3771e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3823e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1566e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 27.1323
# Mean Absolute Percentage Error (MAPE): 0.7055
# Mean Squared Error (MSE): 1578.9703
# Root Mean Squared Error (RMSE): 39.7363
# R-Pearson Correlation Coefficient (R): 0.9973
# R-squared (R2): 0.9937
# Program is running for 10 neurons and 17 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0097
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.8956e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.2856e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.3780e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.4861e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.3713e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0376e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.8832e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2124e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0437e-04
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.3015e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.0473e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.6095e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.6360e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.2921e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7820e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.4429e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.3173e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.0143e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.7712e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.1923e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.9749e-05
# Epoch 23/100
# ...
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0112
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.7561e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.3826e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.5642e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2940e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0277e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0831e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.4442e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4894e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.6874e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.7422e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.9352e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.2380e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5724e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.3807e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.8589e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.7414e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.1450e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2589e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7189e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4913e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6482e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6662e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.5249e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 6ms/step - loss: 5.1837e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8549e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.7132e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 32.2920
# Mean Absolute Percentage Error (MAPE): 0.8438
# Mean Squared Error (MSE): 2012.0619
# Root Mean Squared Error (RMSE): 44.8560
# R-Pearson Correlation Coefficient (R): 0.9963
# R-squared (R2): 0.9920
# Program is running for 10 neurons and 26 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.6308e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.3116e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1693e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.0226e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.4357e-05
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.2695e-05
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.6635e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.4678e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.7864e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0289e-04
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.3073e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4809e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.3248e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.1942e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.0165e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4566e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4931e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.4058e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9000e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6945e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.3748e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.8487e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.9115e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5674e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.7943e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.0180e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.5794e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.2429e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6459e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6833e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4063e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.3571e-05
# Epoch 34/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.3564e-05
# Epoch 35/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.9527e-05
# Epoch 36/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.8515e-05
# Epoch 37/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.6864e-05
# Epoch 38/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.9909e-05
# Epoch 39/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4145e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 25.1993
# Mean Absolute Percentage Error (MAPE): 0.6729
# Mean Squared Error (MSE): 1510.1251
# Root Mean Squared Error (RMSE): 38.8603
# R-Pearson Correlation Coefficient (R): 0.9972
# R-squared (R2): 0.9940
# Program is running for 10 neurons and 27 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 5ms/step - loss: 0.0035
# Epoch 2/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.2046e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.4239e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1321e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1708e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2392e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0474e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.9279e-05
# Epoch 9/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.1127e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.0428e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 9.5286e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5534e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.3005e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5310e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.4778e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.5291e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.0502e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8696e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.7448e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5540e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.8744e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 5ms/step - loss: 6.2156e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.7527e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8462e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.6546e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 5ms/step - loss: 5.7314e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.4679e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.4303e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.5849e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.4871e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.3637e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.9804e-05
# Epoch 33/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.6515e-05
# Epoch 34/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.4882e-05
# Epoch 35/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.7950e-05
# Epoch 36/100
# 439/439 [==============================] - 2s 5ms/step - loss: 4.3106e-05
# Epoch 37/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9229e-05
# Epoch 38/100
# 439/439 [==============================] - 2s 5ms/step - loss: 3.9650e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 26.1525
# Mean Absolute Percentage Error (MAPE): 0.6997
# Mean Squared Error (MSE): 1608.9036
# Root Mean Squared Error (RMSE): 40.1111
# R-Pearson Correlation Coefficient (R): 0.9970
# R-squared (R2): 0.9936
# Program is running for 10 neurons and 28 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0052
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.8827e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 5ms/step - loss: 2.2945e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.7537e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 5ms/step - loss: 1.2342e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.2356e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1247e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1791e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.7046e-05
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.5821e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 5ms/step - loss: 8.0258e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 5ms/step - loss: 7.7029e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.9379e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.2845e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.9283e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5133e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.1386e-05
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.5524e-05
# 110/110 [==============================] - 1s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Mean Absolute Error (MAE): 44.0061
# Mean Absolute Percentage Error (MAPE): 1.1240
# Mean Squared Error (MSE): 2877.7226
# Root Mean Squared Error (RMSE): 53.6444
# R-Pearson Correlation Coefficient (R): 0.9967
# R-squared (R2): 0.9886
# Program is running for 10 neurons and 29 replicate ----->
#
# Epoch 1/100
# 439/439 [==============================] - 5s 4ms/step - loss: 0.0099
# Epoch 2/100
# 439/439 [==============================] - 2s 4ms/step - loss: 3.8209e-04
# Epoch 3/100
# 439/439 [==============================] - 2s 4ms/step - loss: 2.6029e-04
# Epoch 4/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.8149e-04
# Epoch 5/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.5419e-04
# Epoch 6/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.6780e-04
# Epoch 7/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0426e-04
# Epoch 8/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.1110e-04
# Epoch 9/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0448e-04
# Epoch 10/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.9896e-05
# Epoch 11/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.8243e-05
# Epoch 12/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.6489e-05
# Epoch 13/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.6240e-05
# Epoch 14/100
# 439/439 [==============================] - 2s 4ms/step - loss: 9.3436e-05
# Epoch 15/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.4629e-05
# Epoch 16/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.2808e-05
# Epoch 17/100
# 439/439 [==============================] - 2s 4ms/step - loss: 1.0373e-04
# Epoch 18/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.0009e-05
# Epoch 19/100
# 439/439 [==============================] - 2s 4ms/step - loss: 8.1239e-05
# Epoch 20/100
# 439/439 [==============================] - 2s 4ms/step - loss: 6.7010e-05
# Epoch 21/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.7225e-05
# Epoch 22/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.6399e-05
# Epoch 23/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.3983e-05
# Epoch 24/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.8019e-05
# Epoch 25/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.2487e-05
# Epoch 26/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.1164e-05
# Epoch 27/100
# 439/439 [==============================] - 2s 4ms/step - loss: 7.1714e-05
# Epoch 28/100
# 439/439 [==============================] - 2s 4ms/step - loss: 4.4603e-05
# Epoch 29/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.2437e-05
# Epoch 30/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.2089e-05
# Epoch 31/100
# 439/439 [==============================] - 2s 4ms/step - loss: 5.2933e-05
# Epoch 32/100
# 439/439 [==============================] - 2s 6ms/step - loss: 5.7414e-05
# Epoch 33/100
# 439/439 [==============================] - 3s 6ms/step - loss: 4.7858e-05
# 110/110 [==============================] - 1s 4ms/step
# 28/28 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 29.0150
# Mean Absolute Percentage Error (MAPE): 0.7606
# Mean Squared Error (MSE): 1845.1852
# Root Mean Squared Error (RMSE): 42.9556
# R-Pearson Correlation Coefficient (R): 0.9964
# R-squared (R2): 0.9927
# Progress: Collecting outputs.......
#
#
# Progress: All works are done successfully, congratulations!!
#
#
# Best model (neurons, replicate, rmse):  10 11 38.109370031765216
#
# Average scores:
#     neurons       rmse      mape         R  elapsed_time
# 0       10  45.296348  0.837256  0.996649     58.318725
#
# Standard_deviations:
#     neurons      rmse      mape         R  elapsed_time
# 0       10  7.668317  0.194037  0.000836     15.284717
#
# Minimums:
#     neurons      rmse      mape         R  elapsed_time
# 0       10  38.10937  0.629882  0.993451      29.02683
#
# Maximums:
#     neurons       rmse      mape         R  elapsed_time
# 0       10  67.996937  1.435416  0.997572     80.115185

# %%
create_visualization(sl_model_output)

# %% [markdown]
# # ARO Epoch - 10 , Population - 5

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=10, pop_size=5) #epoch = 10 , population size - 5

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam")
print("Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch):", best_hyperparameters.solution)
# Out:
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 159
# 2.0
# 0.08247652604765027
# 9
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 1s 5ms/step
# 2024/01/03 09:33:08 PM, INFO, mealpy.swarm_based.ARO.IARO: Solving single objective optimization problem.
# Root Mean Squared Error (RMSE): 796.7799
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 137
# 0.0
# 0.025607947489921606
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.5219
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 52
# 0.0
# 0.027482993246535668
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.0510
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 41
# 0.0
# 0.006631181995486877
# 15
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.1547
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 35
# 0.0
# 0.08355804750120975
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 27.4625
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 112
# 0.0
# 0.028958370275060315
# 30
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.7860
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 60
# 0.0
# 0.006631181995486877
# 15
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.1968
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 52
# 0.0
# 0.02560286369121438
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 26.9480
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 35
# 0.0
# 0.006631181995486877
# 15
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.2536
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 35
# 0.0
# 0.08355804750120975
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28
best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [5.28196312e+01 0.00000000e+00 2.74829932e-02 9.92145083e+00]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [5.28196312e+01 0.00000000e+00 2.74829932e-02 9.92145083e+00]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 52
# Optimizer : 0
# Learning Rate : 0.0275
# Batch Size : 9

# %% [markdown]
# # Epoch - 10, Population - 15

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=10, pop_size=15) #epoch = 10 , population size - 15

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam")
print("Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch):", best_hyperparameters.solution)
# Out:
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 85
# 0.0
# 0.07771444265499292
# 23
# 22/22 [==============================] - 1s 4ms/step
# 2024/01/03 09:53:50 PM, INFO, mealpy.swarm_based.ARO.IARO: Solving single objective optimization problem.
# Root Mean Squared Error (RMSE): 26.5672
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
# 0.0
# 0.011217295134121678
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 35.9936
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 159
# 0.0
# 0.06890333822084585
# 25
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 25.1367
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 94
# 0.0
# 0.08372196283955181
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.5574
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 61
# 0.0
# 0.009412133298821339
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.2418
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 13
# 2.0
# 0.09619697906127028
# 28
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 47.2159
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 14
# 2.0
# 0.05106216413445241
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 19.9335
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 16
# 0.0
# 0.007457049654731404
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.8075
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 0.0
# 0.06487575538190786
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 27.6295
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 173
# 2.0
# 0.0443331398602515
# 29
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 110.8055
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 2.0
# 0.05097536595760055
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.6372
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 115
# 0.0
# 0.006712985961998252
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.4910
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 161
# 1.0
# 0.015979822655715563
# 30
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 39.1514
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 69
# 2.0
# 0.026945773635486003
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 42.9280
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 21
# 0.0
# 0.02923101232830887
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 19.5751
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 197
# 0.0
# 0.05819296520875661
# 20
# 22/22 [==============================] - 1s 7ms/step
# Root Mean Squared Error (RMSE): 20.7272
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
# 0.0
# 0.017031097748212067
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.4756
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 69
# 0.0
# 0.026945773635486003
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.3245
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 123
# 0.0
# 0.1
# 32
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 113.2089
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 61
# 0.0
# 0.009412133298821339
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.0208
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 173
# 2.0
# 0.0443331398602515
# 28
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 230.5657
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
# 2.0
# 0.05747786018013591
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.7635
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 16
# 0.0
# 0.006793965389640574
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.5318
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 16
# 0.0
# 0.006793965389640574
# 26
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 33.6890
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 14
# 2.0
# 0.05106216413445241
# 32
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 39.9001
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 14
# 2.0
# 0.0511108836783559
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 38.7493
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 115
# 0.0
# 0.006712985961998252
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.7504
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.0037571709983741305
# 32
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 26.0073
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 76
# 2.0
# 0.029466590119463308
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.0326
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.001
# 8
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 26.2334
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.08842195758320222
# 32
# 22/22 [==============================] - 1s 5ms/step
# 2024/01/03 10:04:02 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 1, Current best: 19.575126080101178, Global best: 19.575126080101178, Runtime: 299.25136 seconds
# Root Mean Squared Error (RMSE): 51.6319
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 41
# 0.0
# 0.06487575538190786
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.8990
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 159
# 0.0
# 0.06890333822084585
# 25
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 23.0628
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.1
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 65.0810
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 0.0
# 0.001
# 31
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 40.8502
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.02923101232830887
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 26.8420
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 23
# 0.0
# 0.024539681859435055
# 24
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 25.0492
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.008641049084016725
# 18
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 32.1827
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 57
# 0.0
# 0.06487575538190786
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 28.6131
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 13
# 0.0
# 0.05089696164959594
# 25
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.1534
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 2.0
# 0.048983060349811064
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 21.8179
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 165
# 0.0
# 0.010124777436339362
# 16
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 19.8787
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.016775703566072366
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 17.3894
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 197
# 0.0
# 0.05819296520875661
# 20
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 36.1998
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 21
# 0.0
# 0.060782857977650775
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 35
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 1.0
# 0.037715455156567414
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 39.6380
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 1.0
# 0.05097536595760055
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.9587
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 16
# 0.0
# 0.0622108040596772
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.5782
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 12
# 0.0
# 0.040564794282696715
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 18.9479
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 2.0
# 0.05097536595760055
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 33.0491
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 178
# 0.0
# 0.010954771960132155
# 17
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 32.0065
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.016775703566072366
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.0181
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.007670587173522238
# 28
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 51.4579
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 21
# 0.0
# 0.02923101232830887
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.5832
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 85
# 0.0
# 0.025120123300330595
# 8
# 22/22 [==============================] - 1s 4ms/step
# 2024/01/03 10:38:39 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 7, Current best: 17.389382281354532, Global best: 17.389382281354532, Runtime: 438.45544 seconds
# Root Mean Squared Error (RMSE): 31.4031
# =============================================================================================
# ...
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 25.5558
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 16
# 0.0
# 0.0052025390204054195
# 19
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 45.5705
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 48
# 0.0
# 0.1
# 15
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.7185
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
# 0.0
# 0.0556448782255846
# 27
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.1184
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 44
# 2.0
# 0.05097536595760055
# 16
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 39.4316
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 85
# 0.0
# 0.005132519131519375
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.8781
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 11
# 0.0
# 0.018836596982846437
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 18.7091
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.010902358389656818
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 18.6825
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 12
# 0.0
# 0.02923101232830887
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 21.8538
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.05949444639809465
# 21
# 22/22 [==============================] - 1s 5ms/step
# 2024/01/03 10:44:11 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 8, Current best: 17.389382281354532, Global best: 17.389382281354532, Runtime: 331.49467 seconds
# Root Mean Squared Error (RMSE): 20.4167
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 68
# 0.0
# 0.06487575538190786
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.0826
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 1.0
# 0.028417850762663822
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 56.1045
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 106
# 0.0
# 0.09426045664377919
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 34.1385
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 53
# 0.0
# 0.008292258749451513
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.7816
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.019596865898851845
# 13
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 38.0503
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 13
# 1.0
# 0.046430255059512114
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.6027
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 15
# 0.0
# 0.005404087009141006
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 33.5051
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 28
# 0.0
# 0.07669927885150844
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.6550
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 12
# 0.0
# 0.05566628939585039
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 18.8847
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 1.0
# 0.04107096645948867
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.7733
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 113
# 0.0
# 0.006930511097170973
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.5026
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.016775703566072366
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.3590
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.010902358389656818
# 11
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 35.5312
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 20
# 0.0
# 0.023922102563057053
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 22.8942
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 199
# 0.0
# 0.05949444639809465
# 21
# 22/22 [==============================] - 1s 6ms/step
# 2024/01/03 10:50:42 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 9, Current best: 17.389382281354532, Global best: 17.389382281354532, Runtime: 391.07834 seconds
# Root Mean Squared Error (RMSE): 23.0182
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 41
# 0.0
# 0.06487575538190786
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.5875
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.02923101232830887
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.6422
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 94
# 0.0
# 0.08394264500079705
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.7354
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 61
# 0.0
# 0.009412133298821339
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.7043
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.01823804571715401
# 12
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 20.9259
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 14
# 2.0
# 0.05106216413445241
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.5313
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 15
# 0.0
# 0.0052025390204054195
# 18
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.7511
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 28
# 0.0
# 0.0622108040596772
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.4623
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 12
# 0.0
# 0.05566628939585039
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.6051
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 2.0
# 0.05097536595760055
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 31.4548
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 165
# 0.0
# 0.010124777436339362
# 16
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 27.6926
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.016775703566072366
# 10
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 22.0981
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.010902358389656818
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.0642
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 21
# 0.0
# 0.02923101232830887
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.0126
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.05949444639809465
# 21
# 22/22 [==============================] - 1s 6ms/step
# 2024/01/03 10:55:16 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 10, Current best: 17.389382281354532, Global best: 17.389382281354532, Runtime: 274.19305 seconds
# Root Mean Squared Error (RMSE): 62.2838
# =============================================================================================
# Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam
# Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [10.          0.          0.0167757  10.68831509]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [10.          0.          0.0167757  10.68831509]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 10
# Optimizer : 0
# Learning Rate : 0.0168
# Batch Size : 10

# %% [markdown]
# # ARO Epoch - 10, Population - 50

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=10, pop_size=50) #epoch = 10 , population size - 50

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam")
print("Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch):", best_hyperparameters.solution)
# Out:
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 167
# 1.0
# 0.058862219987794916
# 23
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 1s 5ms/step
# 2024/01/03 11:05:08 PM, INFO, mealpy.swarm_based.ARO.IARO: Solving single objective optimization problem.
# Root Mean Squared Error (RMSE): 23.6383
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 63
# 2.0
# 0.0019454359274411856
# 14
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.8993
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 32
# 2.0
# 0.05858163088114514
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.2647
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 74
# 2.0
# 0.04562463131240118
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 33.6531
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 147
# 0.0
# 0.052387305684725605
# 17
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 55.2652
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 172
# 2.0
# 0.07953971967829804
# 30
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 132.4031
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 98
# 2.0
# 0.016344427773506205
# 26
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 30.9128
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 119
# 0.0
# 0.023044789570544132
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.3731
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 174
# 0.0
# 0.03196093786582474
# 18
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 62.3428
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 29
# 0.0
# 0.08330524824281374
# 20
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 34.5873
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 115
# 1.0
# 0.025427983034323035
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 35.7026
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 95
# 2.0
# 0.041171972487628765
# 30
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.7468
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 153
# 0.0
# 0.04518086882117879
# 16
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 52.7875
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 15
# 1.0
# 0.0699615343615249
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 31.3865
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 22
# 0.0
# 0.009592820392158766
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.0213
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 183
# 0.0
# 0.09221416580275862
# 15
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 192.9390
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 67
# 2.0
# 0.06223069085991634
# 27
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.1309
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 122
# 0.0
# 0.0890429557750291
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 81.0609
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 154
# 1.0
# 0.08627340866202693
# 9
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 22.5674
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 92
# 1.0
# 0.023381658582197
# 27
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.5035
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 160
# 1.0
# 0.00668822537528446
# 11
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 30.8542
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 165
# 2.0
# 0.07137866554379209
# 14
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 98.2674
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 107
# 1.0
# 0.026612020758496707
# 16
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.3193
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 65
# 1.0
# 0.01601320248996085
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.2483
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 112
# 1.0
# 0.01752606408627141
# 12
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.8651
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 131
# 2.0
# 0.0622885760626171
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 47.0519
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 146
# 0.0
# 0.09087546154352254
# 17
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 403.5332
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 177
# 2.0
# 0.04376919876920226
# 25
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 117.2558
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 174
# 0.0
# 0.01324246016625049
# 24
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 26.8979
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 22
# 1.0
# 0.08171300147004776
# 29
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 25.6052
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 170
# 2.0
# 0.008877895524338018
# 24
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 25.8311
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 178
# 2.0
# 0.031048146605245536
# 30
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 23.3538
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 116
# 0.0
# 0.08428640685823192
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 40.8218
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 100
# 0.0
# 0.097096355118614
# 12
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 125.8774
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 100
# 0.0
# 0.0023078415369273244
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 36.3184
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 62
# 2.0
# 0.019250373262636535
# 21
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.3114
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 122
# 0.0
# 0.05192547805071841
# 21
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 28.6431
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 196
# 1.0
# 0.008439704184583993
# 11
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 31.9173
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 196
# 2.0
# 0.06403729748849268
# 27
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 116.1674
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 112
# 1.0
# 0.05811599913955356
# 24
# 22/22 [==============================] - 2s 4ms/step
# Root Mean Squared Error (RMSE): 23.5965
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 11
# 0.0
# 0.023393142332667
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.6058
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 132
# 1.0
# 0.07270063210444476
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.7235
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 64
# 1.0
# 0.06003918150288597
# 26
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.6589
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 177
# 1.0
# 0.034321483976516694
# 22
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 24.1838
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 44
# 1.0
# 0.0411993870587091
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.7844
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 65
# 2.0
# 0.07889455950005776
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.4001
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 186
# 0.0
# 0.08950602905174146
# 10
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 109.4302
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 122
# 0.0
# 0.016256703376000235
# 12
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.3170
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 51
# 2.0
# 0.08496676954929715
# 23
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 39.4872
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
#
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 27.8108
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 1.0
# 0.034321483976516694
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.2708
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 86
# 1.0
# 0.001
# 32
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 134.4204
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 139
# 0.0
# 0.0057584659109678835
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.7325
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.1
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 297.2860
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 107
# 1.0
# 0.031742830537135266
# 19
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 25.0714
# =============================================================================================
# ...
# Values used are : (neurons, optimizer, learning rate, batch size)
# 11
# 0.0
# 0.04376919876920226
# 22
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 25.1675
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 176
# 0.0
# 0.007119084854502446
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 32.7007
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 180
# 1.0
# 0.09469917665853987
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.3581
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 21
# 0.0
# 0.06440198831768217
# 22
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 32.7535
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 37
# 0.0
# 0.08330524824281374
# 28
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 28.0215
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 71
# 1.0
# 0.08627340866202693
# 10
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 22.7374
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 193
# 0.0
# 0.01324246016625049
# 12
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.2160
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 92
# 1.0
# 0.06589147541651263
# 13
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.1822
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 195
# 1.0
# 0.08736398521883493
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.5196
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 88
# 0.0
# 0.021790836090109466
# 25
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 30.8164
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 139
# 0.0
# 0.00668822537528446
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 20.0125
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 161
# 2.0
# 0.041038157528424775
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 32.5896
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.052193093993978784
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 42.3401
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 135
# 1.0
# 0.1
# 9
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 22.0619
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 41
# 0.0
# 0.08330524824281374
# 21
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 28.3509
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 1.0
# 0.1
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.3077
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 110
# 0.0
# 0.021024768399612613
# 24
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 21.3182
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 8
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 24.0168
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 154
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 18.8181
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.02563762006477422
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 42.5203
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 19
# 0.0
# 0.047831592164763265
# 32
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 30.9412
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 123
# 0.0
# 0.01425306368481567
# 10
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 20.3754
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 189
# 0.0
# 0.0268845070054224
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 33.0333
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.001
# 8
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 22.8418
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 17.7358
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 130
# 1.0
# 0.09754429472120775
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 22.3237
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 147
# 0.0
# 0.052193093993978784
# 25
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 42.0675
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 30
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 23.0762
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 14
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 24.9539
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 43
# 0.0
# 0.1
# 32
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 20.8794
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 132
# 0.0
# 0.017148678835004042
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 21.5419
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 99
# 1.0
# 0.07270063210444476
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.5354
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 174
# 1.0
# 0.1
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.3910
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 135
# 1.0
# 0.02323707105904775
# 15
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.9904
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 36
# 0.0
# 0.01623875779772428
# 10
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 22.1947
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 43
# 0.0
# 0.057770360661280704
# 8
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 19.2705
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.06798334246800736
# 21
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 27.0423
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.016256703376000235
# 8
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 18.8150
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 52
# 0.0
# 0.0787165591087406
# 19
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 27.6929
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 19.3053
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 65
# 2.0
# 0.05349507876293773
# 8
# 22/22 [==============================] - 1s 3ms/step
# 2024/01/04 04:01:13 AM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 10, Current best: 17.671731960366095, Global best: 17.671731960366095, Runtime: 1685.57118 seconds
# Root Mean Squared Error (RMSE): 29.6351
# =============================================================================================
# Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam
# Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [1.32706328e+02 0.00000000e+00 4.11776590e-02 8.00000000e+00]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [1.32706328e+02 0.00000000e+00 4.11776590e-02 8.00000000e+00]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 132
# Optimizer : 0
# Learning Rate : 0.0412
# Batch Size : 8

# %% [markdown]
# # ARO Epoch - 5, Population - 100

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neur
best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [1.40307824e+02 0.00000000e+00 7.65360190e-02 2.97710559e+01]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [1.40307824e+02 0.00000000e+00 7.65360190e-02 2.97710559e+01]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 140
# Optimizer : 0
# Learning Rate : 0.0765
# Batch Size : 29

# %% [markdown]
# # Epoch - 10, Population - 100

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=10, pop_size=100) #epoch = 10 , population size - 100

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam")
print("Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch):", best_hyperparameters.solution)
# Out:
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 68
# 1.0
# 0.018412471457296978
# 25
# WARNING:tensorflow:From C:\Users\abdur\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 1s 2ms/step
# 2024/01/04 02:26:33 PM, INFO, mealpy.swarm_based.ARO.IARO: Solving single objective optimization problem.
# Root Mean Squared Error (RMSE): 27.9773
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 48
# 1.0
# 0.04038207289628502
# 12
# 22/22 [==============================] - 0s 1ms/step
# Root Mean Squared Error (RMSE): 30.0612
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 154
# 0.0
# 0.009845741374368687
# 24
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 27.2468
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 181
# 1.0
# 0.07604508916472187
# 12
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 22.8618
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 176
# 2.0
# 0.023313748678276014
# 17
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 24.2144
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 54
# 0.0
# 0.054159468001117636
# 26
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 18.5999
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 109
# 0.0
# 0.006477585173675765
# 29
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 24.3652
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 162
# 1.0
# 0.06284809334129068
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.0519
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 167
# 2.0
# 0.025242503641725013
# 31
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.5203
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 73
# 0.0
# 0.0014649895993753843
# 16
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.1516
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 46
# 1.0
# 0.08137426986920629
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 24.1293
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 128
# 2.0
# 0.07951386805874705
# 15
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 28.4809
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 49
# 2.0
# 0.016888432591712355
# 12
# 22/22 [==============================] - 0s 1ms/step
# Root Mean Squared Error (RMSE): 21.4437
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 108
# 2.0
# 0.042228170441209405
# 24
# 22/22 [==============================] - 0s 1ms/step
# Root Mean Squared Error (RMSE): 31.1009
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 197
# 0.0
# 0.04114153033320687
# 23
# 22/22 [==============================] - 0s 5ms/step
# Root Mean Squared Error (RMSE): 48.3735
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 117
# 0.0
# 0.03546714143585694
# 29
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 20.8362
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 62
# 0.0
# 0.056028612137995086
# 27
# 22/22 [==============================] - 0s 1ms/step
# Root Mean Squared Error (RMSE): 21.0716
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 88
# 0.0
# 0.04512962042846693
# 20
# 22/22 [==============================] - 0s 1ms/step
# Root Mean Squared Error (RMSE): 30.1175
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 113
# 1.0
# 0.004685519264756866
# 27
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 72.0672
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 159
# 0.0
# 0.04734579752448659
# 26
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 23.5382
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 48
# 2.0
# 0.0950892486100705
# 29
# 22/22 [==============================] - 0s 2ms/step
# Root Mean Squared Error (RMSE): 31.2377
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 146
# 0.0
# 0.05649074837355669
# 9
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 54.8067
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 17
# 2.0
# 0.0697153546143894
# 31
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 37.8960
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 110
# 2.0
# 0.04198311688670156
# 13
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.1504
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 71
# 2.0
# 0.004576946769942165
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 38.6078
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 102
# 0.0
# 0.0938763370073152
# 27
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.4288
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 91
# 1.0
# 0.07328126036578088
# 30
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 26.5930
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 186
# 2.0
# 0.06428730680700401
# 24
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 29.1735
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 154
# 0.0
# 0.0356331523697918
# 14
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 85.1759
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 120
# 1.0
# 0.039386176357291976
# 30
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.5843
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 96
# 2.0
# 0.0046865664845069915
# 14
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 27.3794
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 127
# 2.0
# 0.04462093632525716
# 29
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 24.4122
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 50
# 0.0
# 0.055524159047167246
# 12
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 28.0000
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 104
# 2.0
# 0.0685452038376529
# 28
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.1378
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 118
# 1.0
# 0.0734848454639365
# 31
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 26.1450
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 86
# 2.0
# 0.09838839076513191
# 24
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 31.9997
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 189
# 1.0
# 0.017853699430251623
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 25.9818
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
#
# 8
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 19.4218
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 158
# 0.0
# 0.037208209971492365
# 11
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 63.5673
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 34
# 0.0
# 0.03749629748056718
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 20.9570
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.0033411012813292455
# 8
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 20.3963
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 32
# 2.0
# 0.008468379377417717
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.1031
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 26
# 2.0
# 0.0046865664845069915
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 18.3938
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.05270685378442225
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.8813
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 26
# 0.0
# 0.08657835873803156
# 25
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.6092
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 20
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 33.8732
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.006928498321855162
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.1406
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 74
# 0.0
# 0.04311243318709945
# 11
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.8551
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 118
# 0.0
# 0.056011549195183884
# 11
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 57.5495
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 64
# 0.0
# 0.038235657560747656
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.4670
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 34
# 0.0
# 0.006471504495486412
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.1520
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 25
# 0.0
# 0.04788199693616753
# 12
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 31.0318
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 99
# 1.0
# 0.07296276396028595
# 32
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 23.5701
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 128
# 0.0
# 0.037208209971492365
# 12
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 32.2263
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 69
# 0.0
# 0.04068789095557465
# 24
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 21.2350
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 88
# 0.0
# 0.07969588668053729
# 14
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 41.5750
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 196
# 1.0
# 0.045059808671067896
# 29
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 24.5755
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 63
# 0.0
# 0.06839237334414827
# 32
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 19.2813
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 90
# 0.0
# 0.008217639986534402
# 10
# 22/22 [==============================] - 1s 4ms/step
# 2024/01/04 11:58:46 PM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 10, Current best: 17.568903264405122, Global best: 17.568903264405122, Runtime: 3594.15998 seconds
# Root Mean Squared Error (RMSE): 20.2534
# =============================================================================================
# Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam
# Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [6.54358595e+01 0.00000000e+00 6.15413563e-02 1.23097795e+01]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [6.54358595e+01 0.00000000e+00 6.15413563e-02 1.23097795e+01]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 65
# Optimizer : 0
# Learning Rate : 0.0615
# Batch Size : 12

# %% [markdown]
# # ARO Epoch - 15, Population - 100

# %%
# Define the objective function for ARO using RMSE
def objective_function(solution):
    neurons = int(solution[0])  # Number of neurons in LSTM layer
    optimizer = solution[1]
    learning_rate = solution[2]
    batch_size = int(solution[3])

    print("============================================= Running For =============================================")

    print("Values used are : (neurons, optimizer, learning rate, batch size)")
    print(neurons)
    print(optimizer)
    print(learning_rate)
    print(batch_size)

    lstm_model = build_single_layer_LSTM(layers=[neurons], time_step= 5, num_features=num_features, optimizer=optimizer, learning_rate=learning_rate,verbose=0)
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience= 5)
    # Train the model using X_train and y_train
    lstm_model.fit(X_train, y_train, epochs=50, batch_size=batch_size, callbacks=[callback],verbose=0)

    ypred = min_max_inverse_transform(lstm_model.predict(X_test).ravel(), min_test, max_test)
    ytest = min_max_inverse_transform(y_test, min_test, max_test)

    mse =  np.mean((ytest - ypred)**2)
    rmse = np.sqrt(mse)

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print("=============================================================================================")
    return rmse

# Define the bounds for neurons and dropout rate
neurons_bounds = (10,200)  # Assuming a range for neurons (you can adjust this)
optimizers = ('Adam','Adagrad','Nadam')
learning_rates = (0.001,0.1)
batches = (8,32)

bound = (FloatVar(lb=neurons_bounds[0], ub=neurons_bounds[1], name="neurons"),
         StringVar(valid_sets=optimizers, name="optimizer"),
         FloatVar(lb=learning_rates[0], ub=learning_rates[1], name="learning_rate"),
         FloatVar(lb=batches[0], ub=batches[1], name="batch_size"))

problem_dict = {
    "bounds": bound,
    "obj_func": objective_function,
    "minmax": "min",
}

# Initialize ARO optimizer
model = ARO.IARO(epoch=15, pop_size=100) #epoch = 15 , population size - 100

# Solve the optimization problem
best_hyperparameters = model.solve(problem_dict)

print("Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nad
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 56.7094
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 188
# 0.0
# 0.02922637340934879
# 8
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 37.4680
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 138
# 2.0
# 0.04708435965224071
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 26.6852
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 120
# 0.0
# 0.08164067714291035
# 18
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 35.9793
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 47
# 2.0
# 0.04206127491030273
# 12
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.7669
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 131
# 1.0
# 0.1
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.1265
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 120
# 1.0
# 0.04153052016960039
# 8
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 22.6399
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 38
# 0.0
# 0.017737469256538775
# 22
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 22.2632
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 195
# 0.0
# 0.024742512690779993
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 29.6956
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 143
# 2.0
# 0.05026592005869504
# 24
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 41.5020
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 34
# 0.0
# 0.03252157115047936
# 11
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.3419
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 175
# 1.0
# 0.1
# 32
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 22.9959
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 6ms/step
# Root Mean Squared Error (RMSE): 18.6966
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 128
# 0.0
# 0.03481066562690961
# 10
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.8299
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 160
# 0.0
# 0.024742512690779993
# 22
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 33.8783
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 103
# 0.0
# 0.03933327083056953
# 13
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 30.4921
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 22
# 0.0
# 0.010867745773709364
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 27.3638
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 0.0
# 0.01031727036580448
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 17.1972
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 200
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 19.0074
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.01761493701824537
# 15
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 23.9047
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 2.0
# 0.0038638380387475933
# 8
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 22.4207
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 161
# 2.0
# 0.001
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 18.2720
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 29
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 31.9512
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 163
# 0.0
# 0.010761945890025914
# 8
# 22/22 [==============================] - 1s 5ms/step
# Root Mean Squared Error (RMSE): 19.3136
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 122
# 0.0
# 0.05636381623371031
# 26
# 22/22 [==============================] - 1s 3ms/step
# Root Mean Squared Error (RMSE): 23.3290
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 90
# 0.0
# 0.04387094285904321
# 18
# 22/22 [==============================] - 1s 2ms/step
# Root Mean Squared Error (RMSE): 19.9783
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 152
# 2.0
# 0.0018071099395752187
# 8
# 22/22 [==============================] - 1s 4ms/step
# Root Mean Squared Error (RMSE): 20.2832
# =============================================================================================
# ============================================= Running For =============================================
# Values used are : (neurons, optimizer, learning rate, batch size)
# 10
# 0.0
# 0.1
# 29
# 22/22 [==============================] - 1s 3ms/step
# 2024/01/05 09:06:48 AM, INFO, mealpy.swarm_based.ARO.IARO: >>>Problem: P, Epoch: 15, Current best: 17.19718163642685, Global best: 17.19718163642685, Runtime: 4241.89869 seconds
# Root Mean Squared Error (RMSE): 19.2047
# =============================================================================================
# Optimizers : 0 for Adam, 1 for Adagrad, 2 for Nadam
# Best Hyperparameters (Neurons, Optimizer, Learning Rate, Batch): [2.00000000e+02 0.00000000e+00 1.03172704e-02 8.00000000e+00]

# %%
print(best_hyperparameters.solution)

neurons = int(best_hyperparameters.solution[0])
optimizer = int(best_hyperparameters.solution[1])
learning_rate = round(best_hyperparameters.solution[2],4)
batch_size = int(best_hyperparameters.solution[3])

print("=======================================================")
print("Best Hyper-parameters")
print("=======================================================")
print("LSTM Layer neurons : "+str(neurons))
print("Optimizer : "+str(optimizer))
print("Learning Rate : "+str(learning_rate))
print("Batch Size : "+str(batch_size))
# Out:
# [2.00000000e+02 0.00000000e+00 1.03172704e-02 8.00000000e+00]
# =======================================================
# Best Hyper-parameters
# =======================================================
# LSTM Layer neurons : 200
# Optimizer : 0
# Learning Rate : 0.0103
# Batch Size : 8
